# %% [markdown]
# ## Load packages

# %%
import spacy
nlp = spacy.load('C:/Users/clu/Anaconda3/envs/firstprogram/Lib/site-packages/de_core_news_sm/de_core_news_sm-2.0.0')
from spacy import displacy
import sqlite3
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import numpy as np
from operator import itemgetter
import datetime as dt
import matplotlib.dates as mdates
import json

# %% [markdown]
# ## Conncet to database

# %%
conn = sqlite3.connect('./db/dietagespressedata_clean.db')
cur = conn.cursor()

df = pd.read_sql("SELECT id,Titel,Body,Kategorie,Datum,Quelle FROM Artikel WHERE Quelle ='Reuters'", conn, index_col="id", parse_dates=True)
df.shape
df.head()
# Out:
#                                                 Titel  \
# id
# 19  FPÖ warnt: Föhnsturm weht Familienbeihilfe ins...
# 20  Merkel-Rückzug: Unbekannte Nachwuchshoffnung H...
# 21  Lokalaugenschein: Die Tagespresse bei der Leis...
# 22  Unleistbares Eigentum, teure Mieten, wohnen be...
# 23  Entwarnung: Riesiges Bombenpaket an Kickl war ...
#
#                                                  Body Kategorie  \
# id
# 19  Ein ausländischer Föhnsturm ist vergangene Nac...   Politik
# 20  Nach dem Abtritt von Angela Merkel als CDU-Che...      Welt
# 21  Gänsehaut-Feeling am Heldenplatz. Unter der An...   Politik
# 22  Der beliebte Brettspiel-Klassiker „Monopoly“ e...  Finanzen
# 23  Aufatmen im Innenministerium: Nachdem Herbert ...   Politik
#
#                   Datum   Quelle
# id
# 19  2018-10-30 13:38:07  Reuters
# 20  2018-10-29 14:17:22  Reuters
# 21  2018-10-26 11:07:32  Reuters
# 22  2018-10-25 14:36:23  Reuters
# 23  2018-10-25 11:17:25  Reuters

# %%
df.shape
# Out:
# (222, 5)

# %% [markdown]
# ## Save as csv

# %%
df.to_csv(path_or_buf="./datasets/news_de.csv", sep=',',encoding='utf-8')

# %% [markdown]
# ## Count articles per day

# %%
artikelliste={}

for i in range(0, len(df)):
    datum = df.iloc[i]['Datum']
    datum = datum.split(" ")[0]
    
    if datum in artikelliste:
        artikelliste[datum] += 1
    else:
        artikelliste[datum] = 1

# %%
startdatum = "2018-09-30"
enddatum = "2018-10-30"

datelist = pd.date_range(start=startdatum, end=enddatum).tolist()
datelist = pd.to_datetime((datelist))

artikelliste0 =[]
for date in datelist:
    if str(date).split()[0] in artikelliste:
        artikelliste0.append(artikelliste[str(date).split()[0]])
    else:
        artikelliste0.append(0)
        
tickslist = pd.date_range(start=startdatum, end=enddatum, freq='1D').tolist()

plt.plot(datelist, artikelliste0, label="Article count")
plt.axis([startdatum, enddatum, 0, max(artikelliste0)])

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
plt.xlabel('Date')
plt.xticks(tickslist)
plt.ylabel('Count')
plt.suptitle('Articles per day')
plt.gcf().autofmt_xdate()
plt.legend()
plt.savefig('./images/anzahl_de.png', dpi=300)
plt.show()

# %% [markdown]
# ## Mark persons and organizations

# %%
colors = {'ORG': 'red', 'PERSON':'yellow'}
options = {'ents': ['ORG', 'PER'], 'colors': colors}
for i in range(0, 10):
    titel = df.iloc[i]['Titel']
    body = df.iloc[i]['Body']
    doc = nlp(titel)
    doc.user_data['title'] = 'Persons in titel ' + str(i)
    displacy.render(doc, style='ent', jupyter=True, options=options )
# Out:
# <h2 style="margin: 0">Persons in titel 0</h2>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     FPÖ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  warnt: Föhnsturm weht Familienbeihilfe ins Ausland</div>
# <h2 style="margin: 0">Persons in titel 1</h2>
#
# <div class="entities" style="line-height: 2.5">Merkel-Rückzug: Unbekannte Nachwuchshoffnung
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Horst Kurz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  will
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CDU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  übernehmen</div>
# <h2 style="margin: 0">Persons in titel 2</h2>
#
# <div class="entities" style="line-height: 2.5">Lokalaugenschein: Die Tagespresse bei der
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Leistungsschau des
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Bundesheeres</div>
# <h2 style="margin: 0">Persons in titel 3</h2>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Unleistbares Eigentum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , teure Mieten, wohnen bei Eltern: Neues „
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monopoly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# “ für
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Millennials
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  erscheint</div>
# <h2 style="margin: 0">Persons in titel 4</h2>
#
# <div class="entities" style="line-height: 2.5">Entwarnung: Riesiges Bombenpaket an Kickl war nur
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Knallerbse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# </div>
# <h2 style="margin: 0">Persons in titel 5</h2>
#
# <div class="entities" style="line-height: 2.5">„Pokémon Go“ für Vatikan: Geistliche freuen sich auf
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ansturm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  tausender Kinder</div>
# C:\Users\clu\Anaconda3\envs\firstprogram\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <h2 style="margin: 0">Persons in titel 6</h2>
#
# <div class="entities" style="line-height: 2.5">Kassenreform: Der brisante Gesetzesentwurf</div>
# <h2 style="margin: 0">Persons in titel 7</h2>
#
# <div class="entities" style="line-height: 2.5">Krone, Falter,
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Die Presse & Co.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : Ihr Tageshoroskop im großen Überblick</div>
# <h2 style="margin: 0">Persons in titel 8</h2>
#
# <div class="entities" style="line-height: 2.5">Gudenus: Stadt Wien will häufigen, ausländischen Namen „Top“ auf Türschildern vertuschen</div>
# <h2 style="margin: 0">Persons in titel 9</h2>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SPÖ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Kärnten empört: Katze von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Peter Kaiser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  nur auf Platz 12 der EU-Wahlliste</div>

# %%
colors = { 'PER':'red'}
options = {'ents': [ 'PER'], 'colors': colors}
for i in range(0, 2):
    body = df.iloc[i]['Body']
    doc = nlp(body)
    doc.user_data['title'] = 'Persons in text ' + str(i)
    displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <h2 style="margin: 0">Persons in text 0</h2>
#
# <div class="entities" style="line-height: 2.5">Ein ausländischer Föhnsturm ist vergangene Nacht über Österreich gefegt und hat massive Schäden angerichtet. Österreichische Familienbeihilfe in Höhe von mehreren Millionen Euro wurden nach Erkenntnissen des Innenministeriums illegal ins Ausland verweht. Die FPÖ kündigt Konsequenzen an.
# „I bin heut aufgewacht, und mir hobn 114 Euro im Börserl gfehlt”, schildert die vom Unwetter betroffene Jungmutter
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Anita F.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (22). Laut Regierungsaussendung im Krone-Forum sei das Geld vom Sturm ins Ausland geweht worden. „Na super, I wollt mir von der Familienbeihilfe für mei dreimonatige Tochter grad vier Stangen rote Gauloises kaufen. Jetzt gibt sicher irgend so a Kopftuch-Islamerin mei hiesiges Geld für unnötigen Blödsinn aus.“
# FPÖ-Sonderermittler
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Johann Gudenus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ist schockiert vom Ausmaß der Zerstörung: „Es ist kein Zufall, dass wir für die Indexierung der Familienbeihilfe kritisiert werden und plötzlich taucht dieser Föhnsturm auf, der unseren Österreichern das Geld aus dem Börserl weht.
# Verschwörung vermutet
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# Die FPÖ ist inzwischen der Meinung, dass der Klimawandel Schuld an den Wetterkapriolen sei: „Das Wetter ist vom Menschen gemacht. Genauer gesagt, von
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     George Soros
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# “, so
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gudenus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br></br></br>Er hat schon eine Vermutung, woher der Wind weht: von der Ostküste. Er fordert den „Weltjüdischen Kongress zur Kontrolle des globalen Wetters“ auf, die Stürme sofort einzustellen. Außerdem verlangt er eine Stellungnahme zu Vorwürfen, der Föhnsturm wird von
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     George Soros
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  per VR-Brille gesteuert. Dies legte zuvor eine unabhängige Untersuchung des Hundefrisörs der Traumdeuterin von
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gudenus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  nahe.
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# Innenminister
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Herbert Kickl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ist für eine Stellungnahme derzeit nicht erreichbar. Er wurde gestern am Heimweg von einer leichten Windböe in seinem Heliumluftballon erfasst und ins Mittelmeer geweht.
#
#
#
#
#
#
# </div>
# <h2 style="margin: 0">Persons in text 1</h2>
#
# <div class="entities" style="line-height: 2.5">Nach dem Abtritt von
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Angela Merkel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  als CDU-Chefin überschlagen sich in Berlin die Ereignisse. Die bisher unbekannte Nachwuchshoffnung
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Horst Kurz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (32) könnte
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jens Spahn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Friedrich Merz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ausstechen und die angeschlagene Partei übernehmen. Doch noch lässt sich das Jungtalent von den Parteigranden bitten.
# „Wir müssen endlich von der AfD lernen und sie so weit rechts überholen, dass wir dabei den Seitenspiegel von unserem Knorkemobil volle Kanne an der Mittelleitplanke abschlagen“, so
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Horst Kurz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  lächelnd. Er betont jedoch, „bis jetzt natürlich keine Ambitionen zur Übernahme der CDU gehabt zu haben“, während er in seinem Büro die Umzugskartons packt.</br>Bedingungen
# Hinter den Kulissen sind die Verhandlungen aber längst angelaufen. Die Bedingungen für eine Parteiübernahme:
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Horst Kurz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  verlangt volles Durchgriffsrecht, eine Änderung der Parteistatuten und die Umbenennung der Partei in „Liste Horst – Die neue Union“.
# Wähler begeistert
# Laut einer ersten Umfrage können sich 40% der Deutschen vorstellen können,
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Horst Kurz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  zu wählen. „Wir müssen der hässlichen Fratze der AfD etwas Neues gegenüberstellen.
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Endlich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  hat Ausländerfeindlichkeit wieder eine sehr schöne, glattrasierte und supersanfte
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Babyfratze
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# “, zeigt sich
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     IT-Techniker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Michael Nanut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  aus Duisburg begeistert.</br></br></br>Bei einer Pressekonferenz will
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Horst Kurz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  heute erstmals öffentlich Stellung nehmen und in der ARD-Tagesschau weitere Details verschweigen.
#
# </div>

# %% [markdown]
# ## Build list of person counts

# %%
personenliste=dict()

for i in range(0, len(df)):
    body = df.iloc[i]['Body']
    titel = df.iloc[i]['Titel']
    doc = nlp(titel + "\n" + body)
    for ent in doc.ents:
        if ent.label_ == 'PER':
            if ent.text in personenliste:
                personenliste[ent.text] += 1
            else:
                personenliste[ent.text] = 1

# %%
personenliste
# Out:
# {'Bernd Berg': 1,
#  'Salman Ahmed': 1,
#  'Donald Trump': 120,
#  'Xi Jinping': 5,
#  'Phil Noble': 1,
#  'Joko Widodo': 6,
#  'Palu': 34,
#  'Widodo': 4,
#  'Sutopo Purwo Nugroho': 5,
#  'Verwandte': 1,
#  'Lian Gogali': 3,
#  'Yahdi Basma': 1,
#  'Mutiara Sis Al Jufri Airport': 2,
#  'Athit PerawongmethaWidodo': 1,
#  'Ash': 1,
#  'Nugroho': 12,
#  'Heather Nauert': 4,
#  'Hassan Rouhani': 5,
#  'Brendan McdermidJudges': 1,
#  'Adam Mosseri': 1,
#  'Aston Martin': 11,
#  'Verwandte ThemenAston Martin': 1,
#  '“Aston Martin': 1,
#  'James Congdon': 1,
#  'Quest': 1,
#  'Martin': 1,
#  'Ferrari': 1,
#  'Funding Circle': 1,
#  'Kim Jong Un': 7,
#  'Moon Jae-in': 4,
#  'Chad Carroll': 1,
#  'Kim': 18,
#  'Moon': 5,
#  'North': 1,
#  'Kim Hong-Ji': 1,
#  'Jane Doe': 2,
#  'David Harris': 1,
#  'Louie Cook': 1,
#  'Sico Hoelscher Harris LLP': 1,
#  'Srdjan Zivulovic': 3,
#  'Neelie Kroes': 1,
#  'Ron Woodroof': 1,
#  'Senty Bera': 1,
#  'File PhotoAs': 1,
#  'Sjaak Vink': 1,
#  'Vink': 1,
#  'Keytruda': 1,
#  'Mitsubishi Tanabe Pharma’s': 1,
#  'Antara Foto': 8,
#  'Muhammad Adimaja/': 2,
#  'Keith Loveard': 1,
#  'Tjahjo Kumolo': 2,
#  'Prabowo Subianto': 1,
#  'Gerindra': 1,
#  'Subianto': 2,
#  'Achmad Sukarsono': 1,
#  'Sodik Mudjahid': 1,
#  'File PhotoBy': 1,
#  'Bankers': 1,
#  'Trump': 47,
#  'Fred Trump': 3,
#  'Sarah Sanders': 4,
#  'Charles Harder': 1,
#  'Bill de Blasio': 1,
#  'Jonathan Ernst': 4,
#  'Kavanaugh': 220,
#  'Jeff Flake': 20,
#  'Brett Kavanaugh': 66,
#  'Brian Snyder“I': 1,
#  'Jim Bourg': 3,
#  'Christine Blasey Ford': 21,
#  'Mark Judge': 5,
#  'Deborah Ramirez': 6,
#  'Ramirez': 7,
#  'Ford': 9,
#  'Christopher Wray': 4,
#  'Richard Oh': 1,
#  'Mark Krasberg': 1,
#  'Debbie Ramirez’s': 1,
#  'Krasberg': 1,
#  'Jo Miller': 1,
#  'Kavanaugh - Tad Low': 1,
#  'Kerry Berchem - had': 1,
#  'Miller': 1,
#  'Kyle Roda': 1,
#  'Gold': 1,
#  'Oegussa': 1,
#  'Leonhard Foeger/File Photo': 2,
#  'Fan Bingbing': 4,
#  'Jiang': 1,
#  'Fan': 5,
#  'Twitter': 10,
#  'Eric Gaillard': 1,
#  'Roche': 1,
#  'Arnd Wiegmann': 1,
#  'Shire': 7,
#  'Bayer': 2,
#  'DE': 6,
#  'Novo Nordisk': 2,
#  'Gallia Levy': 1,
#  'Rocky Mountains': 1,
#  'Berman': 1,
#  'Michelle Rice': 1,
#  'Rice': 2,
#  'Alnylam': 1,
#  'BioMarin': 1,
#  'Sangamo': 1,
#  'John Furey': 1,
#  'Furey': 1,
#  'Benjamin Drake Daley': 1,
#  'Michael Paul Miselis': 1,
#  'Thomas Walter Gillen': 1,
#  'Cole Evan White': 1,
#  'Robert E. Lee': 1,
#  'Heather Heyer': 1,
#  'James Alex Fields Jr.': 1,
#  'Daley': 2,
#  'Miselis': 3,
#  'Gillen': 1,
#  'Jean Rosenbluth': 1,
#  'David Ryan': 1,
#  'Angel Navarro': 1,
#  'Navarro': 2,
#  'Thomas Cullen': 1,
#  'Cullen': 1,
#  'Stephanie Keith': 1,
#  'Amid Kavanaugh': 1,
#  'Jonathan': 1,
#  'Mike Pence': 5,
#  'Mitch McConnell': 10,
#  'McConnell': 7,
#  'Dianne Feinstein': 3,
#  'Chuck Grassley': 5,
#  'Slideshow': 7,
#  'Leland Keyser': 2,
#  'P.J. Smyth': 3,
#  'Tesla': 22,
#  'Lucy Nicholson': 1,
#  'Lucy Koh': 1,
#  'Elon Musk': 9,
#  'Vuzem': 1,
#  'Gregor Lesnik': 1,
#  'Koh': 3,
#  'James Murdoch': 4,
#  'James MacTaggert Memorial': 1,
#  'David Moir': 1,
#  'Murdoch': 2,
#  'approval’': 1,
#  'Shannon McGahn': 2,
#  'Donald J. Trump': 1,
#  'Jeb Hensarling': 1,
#  'Don McGahn': 2,
#  'Joshua RobertsMcConnell': 1,
#  'Chuck Schumer': 6,
#  'Schumer': 2,
#  'Samarco': 3,
#  'Vale': 2,
#  'BHP Billiton': 1,
#  'Mariana': 2,
#  'Espírito Santo': 1,
#  'Salman': 3,
#  'Salman bin Abdulaziz Al Saud': 2,
#  'Bandar Algaloud/Courtesy': 1,
#  'Bloomberg': 7,
#  'Michael Bloomberg': 2,
#  'Stapleton  ': 1,
#  'Marc La Vorgna': 1,
#  'Ted Cruz': 4,
#  'Beto': 1,
#  'Marsha Blackburn': 4,
#  'Phil Bredesen': 4,
#  'Everytown': 1,
#  'Jonathan ErnstThe': 1,
#  'Barack Obama': 4,
#  'Mike': 2,
#  'Aly Song': 1,
#  'Justin Trudeau': 11,
#  'Tracey Ramsey': 1,
#  'Ramsey': 1,
#  'Bill Morneau': 1,
#  'months’': 1,
#  '” Morneau': 1,
#  'Juan Pablo Castañon': 1,
#  'Coordinador Empresarial': 1,
#  'Katrina Bullock': 2,
#  'Bullock': 1,
#  'Matthew': 6,
#  'Patrick Woodie': 1,
#  'Florence': 3,
#  'Randall HillFair Bluff': 1,
#  'Billy Hammond': 1,
#  'Fair Bluff': 1,
#  'Gavin Smith': 1,
#  'Randy Britt': 1,
#  'Saeid Hashemi Moghadam': 2,
#  'Assadollah Asadi': 1,
#  'Ayatollah Ali Khamenei': 2,
#  'Bahram Qasemi': 3,
#  'Rudy Giuliani': 1,
#  'Villepinte': 3,
#  'Moghadam': 1,
#  'Emmanuel Macron': 2,
#  'Jean-Yves': 1,
#  'Jim Mattis': 5,
#  'Yuri Gripas': 3,
#  'Ricin': 2,
#  'James Mattis': 2,
#  'Philippe Wojazer': 1,
#  'Donna Strickland': 2,
#  'Marie Curie': 1,
#  'Maria Goeppert-Mayer': 1,
#  'Arthur Ashkin': 2,
#  'Goeppert Mayer': 1,
#  'Alessandro Strumia': 1,
#  'Jessica Wade': 1,
#  'CERN': 1,
#  'Gerard Mourou': 1,
#  'Brendan McDermid': 3,
#  'Charles Platiau': 1,
#  'Peter Power“This': 1,
#  'Wade': 1,
#  'Ashkin': 3,
#  'Alfred Nobel': 1,
#  'tmsnrt.rs/2y6ATVW Slideshow': 1,
#  'Robert Lighthizer': 7,
#  'Lighthizer': 1,
#  'Jared Kushner': 4,
#  'Kushner': 15,
#  'John Kelly': 2,
#  'Ivanka': 1,
#  'Luis Videgaray': 4,
#  'Cui Tiankai': 1,
#  'Michael Pillsbury': 1,
#  'Katie Telford': 1,
#  'Gerald Butts': 1,
#  'Hassan Yussuff': 1,
#  'Yussuff': 2,
#  'Chapter': 1,
#  'Trudeau': 11,
#  '  ': 1,
#  'Sonny Perdue': 1,
#  'Videgaray': 3,
#  'Ildefonso Guajardo': 4,
#  'Leah Millis': 2,
#  'Win McNamee': 3,
#  'Mattis': 4,
#  'Raqqa': 3,
#  'Bashar al-Assad': 2,
#  'Larry Kudlow': 2,
#  'Stephen LamKudlow': 1,
#  'Kevin Burns': 1,
#  'Brendan': 1,
#  'Dick Durbin': 3,
#  'Lisa Murkowski': 7,
#  'Altria': 1,
#  'Liza': 1,
#  'Andrea Salgado Rivera': 1,
#  'Ram': 1,
#  'Michelle Krebs': 1,
#  'Jason Miczek': 1,
#  'Mark LaNeve': 1,
#  'Kurt McNeil': 1,
#  'Billy Hayes': 1,
#  'Claudio Borghi': 1,
#  'German Bunds': 1,
#  'Valentin Marinov': 1,
#  'Borghi': 1,
#  'Giuseppe Conte': 1,
#  'Gene McGillian': 1,
#  'Tony Gentile/File Photo': 1,
#  'Model 3s': 2,
#  'Musk': 6,
#  'Gene Munster': 1,
#  'Ivan Feinseth': 2,
#  'Musk “': 1,
#  'Feinseth': 1,
#  'Kay Bailey Hutchison': 3,
#  'Hutchison': 4,
#  'Counter': 1,
#  'Nauert': 1,
#  'Maria Zakharova': 2,
#  'Verwandte ThemenRussia': 1,
#  'Powell': 5,
#  'Jerome Powell': 3,
#  '” Powell': 2,
#  'Eric Rosengren': 1,
#  'Catherine Mann': 1,
#  'Mann': 1,
#  'Matt Blunt': 1,
#  'Christine Lagarde': 1,
#  'David Kelly': 1,
#  'Buenos Aires': 1,
#  'Jeff Bezos': 2,
#  'Verwandte ThemenSenator': 1,
#  'Bernie Sanders': 5,
#  'Marc Wulfraat': 1,
#  'Robert Galbraith': 2,
#  'OSHA': 2,
#  'Tom Gimble': 1,
#  'Brian Snyder': 1,
#  'Ajit Pai': 3,
#  'Aaron P.': 1,
#  'Jerry Brown': 4,
#  'Pai': 1,
#  'states’': 1,
#  'Ed Markey': 1,
#  'Pat Esser': 1,
#  'Wilbur Ross': 2,
#  'Bridge': 2,
#  'Rebecca Cook': 4,
#  'Ross': 1,
#  '\xa0': 11,
#  'Rassini': 2,
#  'Alfa': 2,
#  'Samit Ghosh': 1,
#  'Ghosh': 1,
#  'Carmakers': 3,
#  'Oscar Albin': 1,
#  'Albin': 2,
#  'Greg Edwards': 1,
#  'Mark Makela': 2,
#  'Vernon Madison': 2,
#  'Madison': 16,
#  'Stephen Breyer': 1,
#  'Breyer': 1,
#  'Julius Schulte': 1,
#  'Schulte': 1,
#  'John Roberts': 1,
#  'Bryan Stevenson': 1,
#  'Sonia Sotomayor': 1,
#  'Samuel Alito': 1,
#  'Thomas Govan': 1,
#  'Stephen Paddock': 3,
#  'Jeff Sessions': 5,
#  'Mike Blake/File': 2,
#  'Katie Waldman': 1,
#  'Border Patrol': 1,
#  'Rebecca Akufo-Addo': 1,
#  'Malawi': 1,
#  'Michelle Obama': 1,
#  'Cynthia Brobbey': 1,
#  'Mike Pompeo': 8,
#  'Mary F. Calvert/File': 1,
#  'Kim Kyung-HoonThe': 1,
#  'Koji Endo': 1,
#  'Takeshi Miyao': 1,
#  'Carnorama': 1,
#  'Mary F. CalvertLighthizer': 1,
#  'Fred Thornhill': 1,
#  'JOHN BODE': 1,
#  'GARY MARTIN': 1,
#  'MATTHEW SHAY': 1,
#  'GMA': 1,
#  'MICHAEL DYKES': 1,
#  'EDWARD R. HAMBERGER': 1,
#  'ERIC MEYER': 1,
#  'DAVID KELLY': 1,
#  'JPMORGAN FUNDS': 1,
#  'MIKE LORIZIO': 1,
#  'CHARLES SCHWAB': 1,
#  'Mike Andrews': 1,
#  'Ellen Lord': 1,
#  'Audi': 1,
#  'Rupert Stadler': 1,
#  'Bram Schot': 1,
#  'Stadler': 1,
#  'Ferdinand Piech': 1,
#  'Schot': 1,
#  'Peter Mosch': 1,
#  'Markus Duesmann': 1,
#  'Greenpeace': 2,
#  'Angela Merkel': 4,
#  'Dieter Zetsche': 1,
#  'Verwandte ThemenVolkswagen': 1,
#  'Carlos Tavares': 1,
#  'Juergen Resch': 1,
#  'Andreas Scheuer': 5,
#  'Svenja Schulze': 1,
#  'Fabian Bimmer': 1,
#  'Stefan Bratzel': 1,
#  'Klaus Mueller': 1,
#  'Verwandte ThemenAt': 1,
#  'onExplainer': 1,
#  'Antara': 1,
#  'Sand': 2,
#  'Jens Laerke': 1,
#  'Agus Haryono': 2,
#  'Rosmawati Binti Yahya': 1,
#  'Verwandte ThemenEmboldened': 1,
#  'Chris Coons': 4,
#  'Barbara': 1,
#  'Michael Avenatti': 3,
#  'Julie Swetnick': 3,
#  'Chad Ludington': 1,
#  'Haryono': 1,
#  'Assegaf Umar': 1,
#  'Umar': 3,
#  'Ardi Kurniawan': 1,
#  'Kurniawan': 1,
#  'Gleen Mononutu': 1,
#  'Petra Mandagi': 1,
#  'Brian Sandoval': 1,
#  '” Mynda Smith': 1,
#  'Steve Marcus     ': 1,
#  'Jason Aldean': 1,
#  'Thinkin': 1,
#  'Bill': 1,
#  'Joe McMonigle': 1,
#  'Makan Delrahim': 1,
#  'George W. Bush': 1,
#  'Khalid al-Falih': 1,
#  'Rick Perry': 1,
#  'Enrique Pena Nieto': 3,
#  'Carlos Jasso': 1,
#  'Pena Nieto': 1,
#  'Televisa': 1,
#  'Rose Garden': 1,
#  'Suzanne Plunkett': 1,
#  'Gaven': 2,
#  'Johnson Reefs': 2,
#  'Wei Fenghe': 1,
#  'Courtesy Diana Quinlan': 1,
#  'Anthony Kennedy': 2,
#  'Rachel Carmon': 1,
#  'Susan Collins': 6,
#  'Amy Halsted': 1,
#  'Collins': 9,
#  'Ross Craft': 1,
#  'Approach Resources': 1,
#  'John Hopkins': 1,
#  'Parsley': 1,
#  'Wood Mackenzie': 2,
#  'Timothy Dove': 1,
#  'Truck': 1,
#  'James Walter': 1,
#  'Beth Whited': 1,
#  'Michael O’Neill': 1,
#  'Liz Hampton': 1,
#  'Jarrett Renshaw': 1,
#  'Devika Krishna Kumar': 1,
#  'Collin Eaton': 1,
#  'Scott DiSavino': 1,
#  'Jessica Resnick Ault': 1,
#  'Andres Guerra Luz': 1,
#  'David Gaffen': 1,
#  'Simon Webb': 1,
#  'Brian Thevenot': 1,
#  'Diesel': 1,
#  'Hannibal HanschkeHe': 1,
#  'Ralph Orlowski': 1,
#  'File': 1,
#  'Jason Lee': 1,
#  'Andrew Brunson': 2,
#  'Ismail Cem Halavurt': 1,
#  'Fethullah Gulen': 1,
#  'Gulen -': 1,
#  'Tayyip Erdogan': 1,
#  'Erdogan': 1,
#  'Kim\n': 1,
#  'Ruth Bader Ginsburg': 1,
#  'Joshua Roberts': 4,
#  'Paul Manafort': 1,
#  'Special Counsel Robert Mueller': 1,
#  'Noel Francisco': 1,
#  'Duncan Hunter': 2,
#  'Hunter': 14,
#  'Paul Ryan': 1,
#  '” Campa-Najjar': 2,
#  'Chris Collins': 1,
#  'al Shabaab Islamist': 1,
#  'Maggie Fick': 1,
#  'Vinod Khosla': 2,
#  'Stephen Lam': 1,
#  'Eric Buescher': 1,
#  'Dori Yob Kilmer': 1,
#  'David Geffen': 1,
#  'Michelle Nichols': 1,
#  'Vivian Balakrishnan': 1,
#  'Rakhine': 3,
#  'Zaw Htay': 2,
#  'Mahathir Mohamad': 2,
#  'Aung San Suu Kyi': 2,
#  'Palang Khali': 1,
#  'Michael Dalder': 1,
#  'Reinhard Zirpel': 1,
#  'Tagesspiegel': 1,
#  'Christian Democrats -': 1,
#  "Suu Kyi's": 1,
#  'Aung San Suu': 1,
#  'Tran Dai Quang': 1,
#  'Suu Kyi': 2,
#  'tmsnrt.rs/2y6ATVW': 1,
#  'Comey\n': 1,
#  'James Comey': 2,
#  'Clodagh KilcoyneIn': 1,
#  'Comey': 5,
#  'David Kelley': 1,
#  'Trey Gowdy': 1,
#  'Bob Goodlatte': 1,
#  'Robert Mueller’s': 1,
#  'Goodlatte': 2,
#  'Hillary Clinton’s': 1,
#  'Clinton': 2,
#  'Comey’s': 1,
#  'Rod Rosenstein': 13,
#  'Nadia Hassani': 3,
#  'Andrea ShalalNow': 1,
#  'Hassani': 3,
#  'Green Card Gardner': 1,
#  'Spoonfuls': 1,
#  'Emily Haber': 1,
#  'Heiko Maas': 1,
#  'Syreta Haggray': 1,
#  'Solveig Rietschel': 1,
#  'Andrea Shalal': 1,
#  'Greg Abbott': 3,
#  'Lucas Jackson': 2,
#  'Abbott': 3,
#  'Lupe Valdez': 1,
#  'Sebastian Pinera': 1,
#  'Stephen LamRepublicans': 1,
#  'Lindsay Walters': 1,
#  'Kevin McCarthy': 1,
#  'McCarthy': 4,
#  'Rapper Cardi B': 1,
#  'Rapper Cardi': 1,
#  'Martin Brown': 1,
#  'Jeff Kern': 1,
#  'Kern': 1,
#  'Migos': 1,
#  'Joseph Tacopina': 1,
#  'John Flannery': 2,
#  'Jeff Immelt': 1,
#  'Larry Culp': 1,
#  'Danaher': 2,
#  'Immelt': 1,
#  'Jim Corridore': 1,
#  'Ricardo Moreal': 1,
#  'Juan Carlos Baker': 1,
#  'Henry RomeroHere': 1,
#  'Humira': 1,
#  'Michael Geist': 1,
#  'Amr Alfiky': 1,
#  '” Trudeau': 1,
#  'Chrystia Freeland': 4,
#  'Francois Dumontier': 1,
#  'Wally Smith': 1,
#  'Philippe Couillard': 1,
#  'Auditor Nicole Galloway': 1,
#  'Law': 1,
#  'Galloway': 2,
#  'Eric Olson': 1,
#  'Dominic Raab': 7,
#  'Theresa May': 4,
#  'Jeremy Hunt': 1,
#  'Philip Hammond': 6,
#  'Verwandte ThemenBritain': 1,
#  'JunckerUK Brexit': 1,
#  'Donald Tusk': 2,
#  'Jean-Claude Juncker': 3,
#  'Matthew Fell': 1,
#  'Tusk': 1,
#  'Hunt': 2,
#  'Vytenis Andriukaitis': 1,
#  'Raab': 4,
#  'Andrew Kelvin': 1,
#  'Kelvin': 1,
#  'Paul-Andre Pinsonnault': 1,
#  'Andrew Harnik': 2,
#  'Andy Clark': 2,
#  'Rob Peabody': 2,
#  'Husky': 1,
#  'Phil Skolnick': 1,
#  'Heitkamp': 1,
#  'Heidi Heitkamp': 5,
#  'Aaron P. Bernstein“We': 1,
#  'John Cornyn': 2,
#  'Brett M. Kavanaugh': 3,
#  'Mary F. CalvertThe': 1,
#  'Cornyn': 1,
#  'Jim BourgFlake': 1,
#  'Joe Manchin': 6,
#  'Mary F. Calvert': 2,
#  'Verwandte ThemenTrade': 1,
#  'Pierre Lampron': 1,
#  'Ronald J. Shurer': 1,
#  'Vladimir Putin': 1,
#  'Putin': 2,
#  'Charles M. Elson': 1,
#  'Elson': 1,
#  'Joseph Spak': 1,
#  'Elon': 1,
#  'Garrett Nelson': 1,
#  'Patrick T. Fallon': 2,
#  'Jay Dubow': 1,
#  'Andres Manuel Lopez Obrador': 2,
#  'Jonathan Ernst“The': 1,
#  'Lopez Obrador': 1,
#  'Tester': 1,
#  'Jon Tester': 3,
#  'Mike Segar“Unfortunately': 1,
#  'Hammond': 5,
#  'Juncker': 1,
#  'Jean-Claude Arnault': 2,
#  'Elisabeth Massi Fritz': 1,
#  'Janerik Henriksson': 1,
#  'Bjorn Hurtig': 1,
#  'Sara Danius': 1,
#  'Gudrun Anteman': 1,
#  'Jean Claude Arnault': 1,
#  'Anders Wiklund': 1,
#  'Michel Barnier': 1,
#  'Carlo AllegriThe': 2,
#  'Rachel Mitchell': 6,
#  'Mitchell': 10,
#  'Michael Bromwich': 2,
#  'Saul Loeb': 1,
#  'Anita Hill': 1,
#  'Clarence Thomas': 1,
#  'Jules Epstein': 1,
#  'Alice Stewart': 1,
#  'Mike Cernovich': 1,
#  'Chris Wallace': 1,
#  'Moira Donegan': 1,
#  'Donegan': 1,
#  'Chris Jackson': 1,
#  'Jackson': 1,
#  'Kathleen Pierman': 1,
#  'Pierman': 1,
#  'Phillip Hammond': 1,
#  'Bill Cosby’s': 1,
#  'Bill Cosby': 2,
#  'Cosby': 13,
#  'Janice Dickinson': 2,
#  'Dickinson': 6,
#  'Martin Singer': 1,
#  'Andrea Constand': 1,
#  'clients’': 1,
#  'Phillip Lee': 1,
#  'Lee': 1,
#  'Joe Hinrichs': 1,
#  'Verwandte ThemenFour': 1,
#  'Donald McGahn': 1,
#  'Kellyanne Conway': 3,
#  'Carl Tobias': 1,
#  'Kevin': 1,
#  'Xavier Becerra': 1,
#  'Brown': 2,
#  'Gigi Sohn': 1,
#  'Tom Wheeler': 1,
#  'Jonathan Spalter': 1,
#  'Ri Yong-ho': 1,
#  'Wang Yi': 4,
#  'John Sullivan': 1,
#  'Sergei Lavrov': 1,
#  'Lavrov': 2,
#  'DPRK': 1,
#  'Margot Wallstrom': 1,
#  'Aaron Josefczyk': 1,
#  'John Austin': 1,
#  'Mike Braun': 1,
#  'Joe Donnelly': 2,
#  'Chad P. Bown': 1,
#  'Verwandte ThemenChina': 1,
#  'Carol Hunter': 1,
#  'Mohammad Javad Zarif': 5,
#  'Robert Mueller': 3,
#  'Peter Nicholls': 1,
#  'Robert Ophele': 2,
#  'Ophele': 7,
#  'MiFID II’s': 1,
#  'TOUGHER EQUIVALENCE Waivers': 1,
#  'MiFID': 3,
#  'Liam Fox': 1,
#  'Andrew MacAskill': 1,
#  'Michael Holden': 1,
#  'Marcelo Ebrard': 1,
#  'Steve Marcus': 1,
#  'Mark Hall-Patton': 1,
#  'Schools': 1,
#  'Mike Manley': 1,
#  'Sergio Marchionne': 1,
#  'Marchionne': 4,
#  'Pietro Gorlier': 1,
#  'Alfredo Altavilla': 1,
#  'Manley’s': 1,
#  'Magneti Marelli': 1,
#  'Ermanno Ferrari': 1,
#  'Calsonic Kansei': 1,
#  'Alfa Romeos': 1,
#  'Maseratis': 1,
#  'Manley': 3,
#  'Tim Kuniskis': 1,
#  'Reid Bigland': 1,
#  'Kuniski': 1,
#  'Alfa Romeo': 1,
#  'Harald Wester': 1,
#  'Verwandte ThemenTsunami': 1,
#  'Aulia Arriani': 1,
#  'Arriani': 1,
#  'Wiranto': 1,
#  'Wiwid': 1,
#  'Darwin Fatir': 3,
#  '” Joern Lauterjung': 1,
#  'Geoservices': 1,
#  'Lauterjung': 1,
#  'Chris Wattie': 3,
#  'Jim BourgChristine': 1,
#  'Blasey Ford': 3,
#  'Courtesy Maricopa': 1,
#  'Paul LeBrun': 1,
#  'Bill Montgomery': 1,
#  'Henry Romero“I': 1,
#  '20)19': 1,
#  'Guajardo': 1,
#  'Theresa': 1,
#  'Sergio Moraes': 1,
#  'Santander': 4,
#  'Andrea Orcel': 1,
#  'Kim Kyung-Hoon  ': 1,
#  'Colombo': 2,
#  'Shinzo Abe': 1,
#  'Tatsuya Fukuda': 1,
#  'Kaga': 2,
#  'Mahishini Colonne': 1,
#  'Taro Kono': 1,
#  'Maithripala Sirisena': 1,
#  'Abe': 4,
#  'Nozomu Yoshitomi': 1,
#  'Yasuhara Tohno': 1,
#  'Fukuda': 2,
#  'Yoji Koda': 1,
#  'Rosenstein': 17,
#  'Special Counsel': 1,
#  'Chris Wilson': 1,
#  'Adam Schiff': 1,
#  'Jeb Fain': 1,
#  'Tom Steyer': 1,
#  'Kevin Mack': 1,
#  'Steyer': 1,
#  'Mack': 1,
#  'Dana Rohrabacher': 1,
#  'Devin Nunes': 1,
#  'Zac Petkanas': 1,
#  'Lisa': 1,
#  'Mini': 1,
#  'FRACTURED ROADS': 1,
#  'Zarif': 4,
#  'Chris Wattie“This': 1,
#  'Zoran Zaev': 2,
#  'Oliver Derkoski': 2,
#  'Verwandte ThemenMacedonia': 1,
#  'Hristiajn Mickoski': 1,
#  'Zaev': 2,
#  'Zorica': 1,
#  'Dushko': 1,
#  'Olivera Georgijevska': 1,
#  'Vladimir Kavadarkov': 1,
#  'ESMA': 1,
#  'Gary Locke': 1,
#  'J. Phillip Thompson': 1,
#  'Younger Latino': 1,
#  'Allan Oliver': 1,
#  'George Latimer': 1,
#  'Maria de la Luz Garcia': 1,
#  'Andrew Reamer': 1,
#  'Jay Clayton': 4,
#  'Mary Hansen': 1,
#  'Renaud Laplanche': 1,
#  'Carrie Dolan': 1,
#  'Gregory Wasson': 1,
#  'Wade Miquelon': 1,
#  'Minor Myers': 1,
#  'Mark Cuban': 1,
#  'Christopher Clark': 1,
#  'Vingroup JSC VIC.HM': 1,
#  'Shaun Calvert': 1,
#  'Calvert': 2,
#  'Jim Deluca': 1,
#  'Bill Russo': 1,
#  'under-23': 1,
#  'Damaged': 1,
#  'Fitch Solutions': 1,
#  'Richard Marshall': 1,
#  'Angela Gittens': 1,
#  'Dolphin': 1,
#  'Hurricane Sandy': 1,
#  'Earl Heffintrayer': 1,
#  'Superstorm Sandy': 1,
#  'Sandy': 1,
#  'Eurocontrol': 1,
#  'Heffintrayer': 1,
#  'Gary Moran': 1,
#  'Paul Coughlan': 1,
#  'Coughlan': 1,
#  'Derek Evans': 1,
#  'Osler': 1,
#  'Mark': 1,
#  'Jeffress': 1,
#  'Rush Limbaugh': 1,
#  '     ': 2,
#  'Mark Blinch': 1,
#  'Bredesen': 9,
#  'Bob Corker': 3,
#  'Blackburn': 7,
#  'Hillary Clinton': 2,
#  'Vox Populi Polling': 1,
#  'Mike Segar/File Photo': 1,
#  'Kamala Harris': 1,
#  'Harris': 1,
#  'Verwandte ThemenMcConnell': 1,
#  'John Clune': 2,
#  'Debbie': 1,
#  'Alex Wroblewski': 1,
#  'Murkowski': 3,
#  'Kavanaugh qualified?’': 1,
#  'Saint-Valerien-de-Milton': 1,
#  'Mike Theiler': 1,
#  'Thomas Lembong': 1,
#  'Lembong': 1,
#  'Tom Williams': 2,
#  'Mark Schiefelbein': 1,
#  'Wang': 1,
#  'Carlos BarriaThe': 1,
#  'Signing Ceremony': 1,
#  'Rod': 1,
#  'Rosenstein?Instant View': 1,
#  'Chris WattieIf': 1,
#  'Sessions': 3,
#  'Andrew McCabe': 2,
#  'Robert) Mueller': 2,
#  'McCabe': 6,
#  'Sally Yates': 1,
#  "Robert Mueller's": 1,
#  'Mueller': 1,
#  'DOJ': 1,
#  'Marko': 1,
#  'Conway': 1,
#  'Karwan Anwar': 1,
#  'Qubad Talabani': 1,
#  'Masoud Barzani': 1,
#  'Masrour Barzani': 1,
#  'Talabani': 1,
#  'KDP': 1,
#  'Halima Ahmed': 1,
#  'Belnd Omar': 1,
#  'Nechirvan Mustafa': 1,
#  'Hassan Dalloush': 1,
#  'Roa Roa Hotel': 1,
#  'Grieve': 1,
#  'Jusuf Kalla': 2,
#  'Budi Waseso': 1,
#  'Sri Mulyani Indrawati': 1,
#  'Pope Francis': 1,
#  'Yuri GripasLighthizer': 1,
#  'Charlie Rose': 1,
#  'Fareed Zakaria GPS': 1,
#  'John Bolton': 2,
#  'Pompeo': 1,
#  'Bolton': 1,
#  "Brett Kavanaugh's": 1,
#  'Tiger Woods': 1,
#  'Mike SegarThe': 1,
#  'Terry Branstad': 2,
#  'Thomas PeterU.S.': 1,
#  'Erik De CastroBeijing': 1,
#  'Imran Khan': 1,
#  'Khan': 3,
#  'Yao Jing': 1,
#  '” Yao': 1,
#  'Yao': 2,
#  'Andrew Small': 1,
#  'Miftah Ismail': 1,
#  'Ri Yong Ho': 2,
#  'Ri': 6,
#  '” Trump': 1,
#  'Edgar Su': 1,
#  'Deborah Ramirez’s': 1,
#  'Raj Shah': 1,
#  'Patrick Morrisey': 2,
#  'Mike TheilerManchin': 1,
#  'Jennifer Maher': 2,
#  'Victoria Long': 1,
#  'Andrew Martino': 1,
#  'Martino': 1,
#  'Brigadier General': 1,
#  'Julian Alford': 1,
#  'Nat Fahy': 1,
#  'Onesja Johnson': 1,
#  'Johnson': 1,
#  'Sombra Torres': 1,
#  'Steven Heim': 1,
#  'Steve Jobs': 1,
#  'Antonio Gracias': 1,
#  'Erik Gordon': 1,
#  'Bobby Yip': 1,
#  'Edgard Garrido': 1,
#  'Peter Navarro': 1,
#  'Automaker': 1,
#  'Josh Hawley': 1,
#  'Kevin Lamarque': 1,
#  'Allies’': 1,
#  'Feinstein': 2,
#  'MIA Recognition Day': 1,
#  'Cruz': 14,
#  "Beto O'Rourke": 2,
#  'Nathan Hunsinger': 1,
#  'Tom Fox': 1,
#  'Emily Miller': 1,
#  'Aaron P. Bernstein': 1,
#  'Douglas High School': 1,
#  'Anthony Portantino': 1,
#  'Fred Greaves': 1,
#  'Daniel Reid': 1,
#  'Mike Blake/File Photo': 1,
#  'Simon Haeder': 1,
#  'Thad Cochran': 1,
#  'Cindy Hyde-Smith': 1,
#  'Karin Housley': 1,
#  'Tina Smith': 1,
#  'Smith': 1,
#  'Al Franken': 1,
#  'Kris Kobach’s': 1,
#  'Kobach': 1,
#  'Lou Barletta': 1,
#  'Bob Casey': 1,
#  'Carlos Barria': 1,
#  'James White': 1,
#  'Zach Moak': 1,
#  'Warren Strain': 1,
#  'Zack Moak': 1,
#  'Patrolman James White': 1,
#  'Marquis Aaron Flowers': 1,
#  'Brookhaven': 1,
#  'Phil Bryant': 1,
#  'Adam Austen': 1,
#  'Ahmed Mahgoub': 1,
#  'Photos': 1,
#  'APART’': 1,
#  'Debra Katz': 1,
#  'Katz': 1,
#  'Mazie Hirono': 1,
#  'John Kennedy': 1,
#  'Flake': 1,
#  'Maria Gallagher': 1,
#  'Ana Maria Archila': 1,
#  'Jeff': 1,
#  'Christine Blasey Ford’s': 2,
#  'Donald Trump Jr.': 1,
#  'Neil Gorsuch': 1,
#  'Dean Heller': 1,
#  'Heller': 3,
#  'Rand Paul': 1,
#  'Paul': 1,
#  'Ben Sasse': 1,
#  'Obamacare': 1,
#  'Manchin': 1,
#  'Doug Jones': 1,
#  'Gorsuch': 2,
#  'Bill Nelson': 1,
#  'Nelson': 1,
#  'Richard Cowan': 1,
#  'Amanda Becker': 1,
#  'Lawrence Hurley': 1,
#  'Trump-Kim': 1,
#  'Stephen Biegun': 1}

# %% [markdown]
# ## Save countlist

# %%
import json
json = json.dumps(personenliste)
f = open("./datasets/personenliste_en.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Clean list

# %%
def cleandict_en(inputdict):
    
    dict2 = inputdict.copy()
    for key in inputdict.keys(): 
        if key.startswith("\\"):
            del dict2[key]
        if key.strip() == "":
            del dict2[key]
        if key.strip() == "Verwandte ThemenFactbox":
            del dict2[key]
        if key.strip() == "Sgt":
            del dict2[key]
        
    return dict2

# %%
personenclean = cleandict_en(personenliste)

# %% [markdown]
# ## Map personnames together (i.e. "Donald Trump" and "Trump")

# %%
def listekompakt(inputdict):
    outputdict = {}

    for name, num in inputdict.items():
        for key in inputdict.keys():            
            if (name == key):
                continue
            if (name in key) and (inputdict[name] > 5):
                inputdict[name] += num
                inputdict[key] = 0
                break
    for name, num  in inputdict.items():
        if num > 0:
            outputdict[name] = num
    return outputdict

# %%
personenkompakt = listekompakt(personenclean)

# %%
import json
json = json.dumps(personenkompakt)
f = open("./datasets/personenliste_en_clean.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Barchart of sortet counts

# %%
personen = sorted(personenkompakt.items(), key=itemgetter(1),reverse=True)

names = list(zip(*personen))[0][0:40]
values = list(zip(*personen))[1][0:40]
x_pos = np.arange(len(names)) 

plt.xticks(rotation='vertical')
plt.subplots_adjust(bottom=0.2)
plt.bar(x_pos, values)
plt.xticks(x_pos, names) 
plt.suptitle('Persons in the News')
plt.savefig('./images/hauefigkeit_news_en.png', dpi=300)
plt.show()

# %% [markdown]
# ## Build list of counts per day

# %%
datumliste={}

for i in range(0, len(df)):
    body = df.iloc[i]['Body']
    titel = df.iloc[i]['Titel']
    datum = df.iloc[i]['Datum']
    datum = datum.split(" ")[0]
    doc = doc = nlp(titel + "\n" + body)
    for ent in doc.ents:
        if ent.label_ == 'PER':
            if ent.text in datumliste:
                if datum in datumliste[ent.text]:
                    datumliste[ent.text][datum] += 1
                else:
                    datumliste[ent.text][datum] = 1
            else:
                datumliste[ent.text] = {}
                datumliste[ent.text][datum] = 1

# %%
datumliste
# Out:
# {'Anita F.': {'2018-10-30': 1},
#  'Johann Gudenus': {'2018-10-30': 1,
#   '2018-10-22': 1,
#   '2018-09-06': 1,
#   '2018-09-04': 1,
#   '2018-08-10': 1,
#   '2018-05-09': 1},
#  '\n': {'2018-10-30': 2,
#   '2018-10-26': 1,
#   '2018-10-24': 1,
#   '2018-10-11': 3,
#   '2018-10-10': 2,
#   '2018-10-08': 1,
#   '2018-10-05': 1,
#   '2018-10-04': 1,
#   '2018-10-03': 1,
#   '2018-09-26': 1,
#   '2018-09-25': 1,
#   '2018-09-21': 1,
#   '2018-09-13': 1,
#   '2018-08-30': 1,
#   '2018-08-29': 1,
#   '2018-08-24': 5,
#   '2018-08-20': 1,
#   '2018-08-14': 2,
#   '2018-08-08': 2,
#   '2018-07-26': 1,
#   '2018-07-24': 1,
#   '2018-07-11': 1,
#   '2018-07-10': 1,
#   '2018-07-05': 1,
#   '2018-07-02': 2,
#   '2018-06-28': 1,
#   '2018-06-25': 1,
#   '2018-06-21': 1,
#   '2018-06-20': 1,
#   '2018-06-19': 2,
#   '2018-06-18': 1,
#   '2018-06-14': 1,
#   '2018-06-13': 2,
#   '2018-06-05': 1,
#   '2018-06-04': 1,
#   '2018-06-01': 1,
#   '2018-05-28': 1,
#   '2018-05-14': 1,
#   '2018-05-09': 2,
#   '2018-05-08': 2,
#   '2018-04-27': 1},
#  'George Soros': {'2018-10-30': 2,
#   '2018-09-27': 1,
#   '2018-08-24': 1,
#   '2018-05-03': 1},
#  'Gudenus': {'2018-10-30': 2,
#   '2018-10-22': 3,
#   '2018-09-06': 4,
#   '2018-09-04': 1,
#   '2018-08-10': 2,
#   '2018-05-09': 1},
#  'Herbert Kickl': {'2018-10-30': 1,
#   '2018-10-26': 1,
#   '2018-10-25': 1,
#   '2018-10-18': 1,
#   '2018-10-10': 1,
#   '2018-10-03': 1,
#   '2018-10-02': 5,
#   '2018-10-01': 1,
#   '2018-09-25': 3,
#   '2018-09-17': 1,
#   '2018-09-05': 1,
#   '2018-09-04': 1,
#   '2018-08-29': 2,
#   '2018-08-07': 1,
#   '2018-07-12': 1,
#   '2018-06-22': 1,
#   '2018-06-13': 1,
#   '2018-06-05': 1,
#   '2018-05-24': 1,
#   '2018-05-17': 1},
#  'Horst Kurz': {'2018-10-29': 6},
#  'Angela Merkel': {'2018-10-29': 1, '2018-09-20': 1, '2018-06-13': 1},
#  'Jens Spahn': {'2018-10-29': 1},
#  'Friedrich Merz': {'2018-10-29': 1},
#  'Endlich': {'2018-10-29': 1},
#  'Babyfratze': {'2018-10-29': 1},
#  'IT-Techniker': {'2018-10-29': 1},
#  'Michael Nanut': {'2018-10-29': 1},
#  'Kunasek': {'2018-10-26': 2, '2018-06-05': 1},
#  'Vize-Kanzler Strache': {'2018-10-26': 1},
#  'Sebastian Kurz': {'2018-10-26': 1,
#   '2018-10-24': 1,
#   '2018-10-23': 1,
#   '2018-10-16': 1,
#   '2018-10-03': 1,
#   '2018-09-26': 4,
#   '2018-09-25': 1,
#   '2018-09-21': 1,
#   '2018-09-20': 1,
#   '2018-09-14': 1,
#   '2018-09-11': 1,
#   '2018-09-10': 1,
#   '2018-09-05': 1,
#   '2018-09-03': 1,
#   '2018-08-28': 1,
#   '2018-08-08': 1,
#   '2018-08-01': 1,
#   '2018-07-19': 1,
#   '2018-07-18': 2,
#   '2018-07-05': 1,
#   '2018-07-04': 1,
#   '2018-07-03': 1,
#   '2018-06-25': 2,
#   '2018-06-19': 1,
#   '2018-06-15': 1,
#   '2018-06-05': 1,
#   '2018-06-01': 1,
#   '2018-05-30': 1,
#   '2018-05-22': 1,
#   '2018-05-15': 2,
#   '2018-05-13': 2,
#   '2018-05-09': 1,
#   '2018-05-07': 1},
#  'Checkfelix': {'2018-10-26': 1},
#  'Kleiner': {'2018-10-26': 1},
#  'Erheiterndes Missverständnis': {'2018-10-26': 1},
#  'Alexander Van der Bellen': {'2018-10-26': 1,
#   '2018-10-15': 1,
#   '2018-10-10': 1,
#   '2018-09-26': 2,
#   '2018-08-06': 1},
#  'Lilli Licka': {'2018-10-26': 1},
#  'Heinz-Christian Strache': {'2018-10-26': 1,
#   '2018-10-10': 1,
#   '2018-10-03': 1,
#   '2018-09-21': 1,
#   '2018-09-14': 1,
#   '2018-08-08': 1,
#   '2018-06-08': 1,
#   '2018-05-30': 1,
#   '2018-05-16': 1,
#   '2018-05-09': 1,
#   '2018-05-07': 1,
#   '2018-05-03': 1},
#  'ZWISCHENFALL': {'2018-10-26': 1},
#  'Mmmm': {'2018-10-26': 1},
#  'Harald Vilismky': {'2018-10-26': 1},
#  'Jenny': {'2018-10-26': 1, '2018-05-08': 1},
#  'Van Der Bellen': {'2018-10-26': 1},
#  'Unleistbares Eigentum': {'2018-10-25': 1},
#  'Monopoly': {'2018-10-25': 2, '2018-04-30': 1},
#  'Millennials': {'2018-10-25': 1},
#  'Arnold Tobolka': {'2018-10-25': 1},
#  'René Benko': {'2018-10-25': 1},
#  '\xa0': {'2018-10-25': 1, '2018-10-23': 1, '2018-06-14': 1, '2018-06-01': 1},
#  'Grätzl': {'2018-10-25': 1},
#  'Du': {'2018-10-25': 1, '2018-09-01': 1, '2018-07-26': 1},
#  'Landet': {'2018-10-25': 1},
#  'Knallerbse\n': {'2018-10-25': 1},
#  'Befürchtungen': {'2018-10-25': 1},
#  'Kickl': {'2018-10-25': 1,
#   '2018-09-25': 1,
#   '2018-09-04': 1,
#   '2018-08-29': 3,
#   '2018-06-13': 1},
#  'Herbert': {'2018-10-25': 1, '2018-10-05': 1},
#  'Ansturm': {'2018-10-24': 1},
#  'Follow': {'2018-10-24': 1},
#  'Claudius': {'2018-10-24': 1},
#  'Heinrich': {'2018-10-24': 1, '2018-05-09': 1},
#  'Jesus': {'2018-10-24': 1, '2018-06-20': 3},
#  'Spannende': {'2018-10-24': 1},
#  '\nLagerhausify': {'2018-10-24': 1},
#  '\nSaudible': {'2018-10-24': 1},
#  '\nWatchapoo': {'2018-10-24': 1},
#  '\n\n': {'2018-10-24': 1,
#   '2018-10-23': 2,
#   '2018-10-22': 1,
#   '2018-09-26': 1,
#   '2018-09-01': 2,
#   '2018-08-29': 1,
#   '2018-08-20': 1,
#   '2018-08-03': 2,
#   '2018-07-16': 1,
#   '2018-07-11': 1,
#   '2018-06-18': 1,
#   '2018-06-15': 1,
#   '2018-04-30': 1},
#  'Krebse': {'2018-10-23': 1},
#  'Michael Ludwig': {'2018-10-23': 1,
#   '2018-10-08': 1,
#   '2018-10-01': 2,
#   '2018-09-24': 1},
#  'Florian Klenk': {'2018-10-23': 1,
#   '2018-10-18': 2,
#   '2018-10-03': 2,
#   '2018-09-27': 1,
#   '2018-09-25': 1,
#   '2018-09-12': 1,
#   '2018-09-10': 1,
#   '2018-07-04': 5},
#  'Saturn': {'2018-10-23': 1},
#  'Hanni': {'2018-10-23': 1},
#  'Uranus': {'2018-10-23': 1},
#  'Vollmond': {'2018-10-23': 1},
#  'Vergessen': {'2018-10-23': 1},
#  'Ihrem': {'2018-10-23': 1},
#  'Christian Rainer': {'2018-10-23': 1},
#  'Jupiter': {'2018-10-23': 1},
#  'Stier': {'2018-10-23': 1},
#  'Bin Innenpolitik-Redakteur': {'2018-10-23': 1},
#  'Salomon': {'2018-10-23': 1},
#  'Melde': {'2018-10-23': 1},
#  'Jungfrauen': {'2018-10-23': 1},
#  '\nGeht': {'2018-10-22': 1},
#  'Peter Kaiser': {'2018-10-22': 2},
#  'Sohn Luca': {'2018-10-22': 1},
#  '\nKatze': {'2018-10-22': 1},
#  'Mutzi Kaiser': {'2018-10-22': 1},
#  'Heinz-Christian Straches Hündin Odi': {'2018-10-22': 1},
#  'Politexperte Filzmaier': {'2018-10-22': 1},
#  'Hass': {'2018-10-22': 1},
#  'Katze': {'2018-10-22': 1},
#  'Peter Kaisers': {'2018-10-22': 1},
#  'Fiffi': {'2018-10-22': 1},
#  'Thomas Drozda': {'2018-10-22': 1},
#  'Offizielle Preisliste': {'2018-10-19': 1},
#  'Oida': {'2018-10-19': 2, '2018-10-18': 1},
#  'Du Rassist': {'2018-10-19': 1},
#  'Wendy': {'2018-10-19': 1},
#  'Wochenblick': {'2018-10-19': 1},
#  'Schwarzafrikaner': {'2018-10-18': 1},
#  'Asylwerber': {'2018-10-18': 1},
#  'Wen': {'2018-10-18': 2, '2018-09-13': 1},
#  'Bitte': {'2018-10-18': 1, '2018-06-08': 1},
#  'Khashoggi': {'2018-10-18': 2, '2018-10-16': 1},
#  'Donald Trump': {'2018-10-18': 1,
#   '2018-09-06': 1,
#   '2018-07-26': 2,
#   '2018-06-28': 1,
#   '2018-06-13': 1,
#   '2018-06-12': 1,
#   '2018-06-11': 1,
#   '2018-05-09': 1},
#  'Mohammed bin Salman': {'2018-10-18': 1, '2018-10-16': 1},
#  'E-Scooter-SUV\n': {'2018-10-17': 1},
#  'Menschenmüll': {'2018-10-17': 1},
#  'Kommt Claudius': {'2018-10-17': 1},
#  'David A.': {'2018-10-16': 2},
#  'Franco Foda': {'2018-10-16': 1},
#  'Alexander Wrabetz': {'2018-10-16': 1, '2018-06-29': 1, '2018-06-14': 1},
#  'Rainer Pariasek': {'2018-10-16': 1,
#   '2018-06-19': 1,
#   '2018-06-14': 2,
#   '2018-06-04': 1},
#  'Ultras': {'2018-10-16': 1},
#  'Jamal Khashoggi': {'2018-10-16': 1},
#  'Kronprinz Mohammed bin Salman': {'2018-10-16': 1},
#  'Khashoggis': {'2018-10-16': 1},
#  'Hofer': {'2018-10-15': 6,
#   '2018-10-04': 3,
#   '2018-10-01': 6,
#   '2018-09-04': 1,
#   '2018-08-22': 2,
#   '2018-07-23': 5},
#  'Verkehrsminister Norbert Hofer': {'2018-10-15': 1,
#   '2018-10-04': 1,
#   '2018-10-01': 1,
#   '2018-07-23': 1,
#   '2018-06-29': 1},
#  'Dieter Böhmdorfer': {'2018-10-15': 1},
#  'Peter Filzmaier': {'2018-10-15': 1, '2018-08-10': 1, '2018-06-25': 1},
#  'Doris Bures': {'2018-10-15': 1, '2018-09-21': 1, '2018-09-01': 2},
#  'Herrn Hofer': {'2018-10-15': 1},
#  'Büromöbel': {'2018-10-15': 1},
#  'Post': {'2018-10-13': 1},
#  'Exklusiv-Interview': {'2018-10-11': 1},
#  'Jörg Haider': {'2018-10-11': 4, '2018-06-28': 1, '2018-05-22': 1},
#  'Wolfgang Fellner': {'2018-10-11': 1, '2018-08-17': 1, '2018-08-16': 3},
#  'Jörg-Haider-Medaille': {'2018-10-11': 1},
#  'Wahres': {'2018-10-11': 1},
#  'Haider': {'2018-10-11': 9},
#  'Norbert Hofer': {'2018-10-11': 1,
#   '2018-09-25': 2,
#   '2018-09-04': 1,
#   '2018-08-22': 1,
#   '2018-08-17': 1,
#   '2018-08-06': 1,
#   '2018-07-23': 1,
#   '2018-07-19': 1,
#   '2018-07-13': 1,
#   '2018-06-19': 1,
#   '2018-05-19': 1,
#   '2018-05-07': 1},
#  '\nFellner': {'2018-10-11': 1, '2018-08-16': 1},
#  'Eristoff': {'2018-10-11': 1, '2018-07-26': 1},
#  'Muammar al-Gaddafi': {'2018-10-11': 1},
#  'Saddam Hussein': {'2018-10-11': 1},
#  'Hussein': {'2018-10-11': 1},
#  'Danke': {'2018-10-11': 1,
#   '2018-09-27': 1,
#   '2018-09-24': 1,
#   '2018-09-21': 1,
#   '2018-07-30': 1,
#   '2018-06-20': 1,
#   '2018-06-15': 1},
#  'Fellners Kopf': {'2018-10-11': 1},
#  'Fellner': {'2018-10-11': 1, '2018-08-16': 1},
#  'Ferdinand Weghitler': {'2018-10-11': 1},
#  'Wast': {'2018-10-11': 1},
#  'Manch': {'2018-10-10': 1},
#  'Mathias Strolz': {'2018-10-10': 1},
#  '\nNorbert Hofer': {'2018-10-10': 1},
#  '\nThomas Glavinic': {'2018-10-10': 1},
#  '\nMaria Vassilakou': {'2018-10-10': 1},
#  'Harald Vilimsky': {'2018-10-10': 1,
#   '2018-09-06': 1,
#   '2018-08-29': 1,
#   '2018-06-08': 1,
#   '2018-06-05': 1,
#   '2018-04-27': 2},
#  'Robert Lugar': {'2018-10-10': 1, '2018-10-05': 1},
#  '\nHarald Mahrer': {'2018-10-10': 1, '2018-05-18': 1},
#  'Wem': {'2018-10-10': 1, '2018-10-04': 1},
#  '\nPeter Pilz': {'2018-10-10': 1},
#  'Vinci': {'2018-10-10': 1},
#  'Beate Meinl-Reisinger': {'2018-10-10': 1, '2018-09-22': 1},
#  '\nSebastian Kurz': {'2018-10-10': 1},
#  'Philippa': {'2018-10-10': 4, '2018-05-03': 1},
#  'Geburt': {'2018-10-10': 1},
#  'Strache': {'2018-10-10': 1, '2018-05-03': 1},
#  'Shitstorm': {'2018-10-09': 1},
#  'Sigi-Maurer-Urteil': {'2018-10-09': 1},
#  'Sigi Maurer': {'2018-10-09': 3},
#  'Stefan Apostol': {'2018-10-09': 2},
#  'Geschah': {'2018-10-09': 1},
#  'Rechtsexperten': {'2018-10-09': 1},
#  '\n\r\n\n\n\n\n\n': {'2018-10-09': 1},
#  'Content-Blocker': {'2018-10-08': 1},
#  'Daniel Brinnich': {'2018-10-08': 1},
#  'Sebastian Trump': {'2018-10-08': 1},
#  'Riesen-Kürbis –': {'2018-10-08': 1},
#  'Martin Kotynek': {'2018-10-08': 1},
#  'Hat Banksy': {'2018-10-08': 1},
#  'Banksy': {'2018-10-08': 2},
#  'Christian Kern': {'2018-10-08': 1,
#   '2018-09-28': 2,
#   '2018-09-22': 1,
#   '2018-09-21': 2,
#   '2018-09-18': 2,
#   '2018-09-01': 1,
#   '2018-08-17': 1,
#   '2018-08-10': 1,
#   '2018-07-19': 1,
#   '2018-05-16': 2,
#   '2018-05-01': 1},
#  'Lassen': {'2018-10-08': 2, '2018-09-18': 1, '2018-08-20': 1},
#  'Nutella \n\n\n\n\n\n\n': {'2018-10-08': 1},
#  'Craftbeer-Start-Up “Wixxer': {'2018-10-08': 1},
#  'Lebe': {'2018-10-08': 1},
#  'Mag': {'2018-08-15': 1},
#  'Fachlehrerin': {'2018-08-15': 1},
#  'Löhne \n\n\n\n\n\n\nVolk': {'2018-08-15': 1},
#  '\n\n\n\n\n\n\nHarald Mahrer': {'2018-08-15': 1},
#  'Harald Mahrer \n\n\n\n\n\n\n\n': {'2018-08-15': 1},
#  'Anti-Depressiva': {'2018-08-15': 1},
#  'Gernot \n\n\n\n\n\n\nJohanna \n\n\n\n\n\n\n': {'2018-08-15': 1},
#  'Mohammed \n\n\n\n\n\n\n\n': {'2018-08-15': 1},
#  'Wickl': {'2018-08-15': 1},
#  'Richtig': {'2018-08-15': 4, '2018-07-06': 1},
#  'John F. Kennedy': {'2018-08-15': 1},
#  'Faymann': {'2018-08-15': 1},
#  'Alfred Mayr': {'2018-08-14': 1},
#  'Mayr': {'2018-08-14': 2},
#  'Alles': {'2018-08-14': 1},
#  'Klicks': {'2018-08-14': 1},
#  'Ladendiebstähle': {'2018-08-14': 1},
#  'Tom Sawyer': {'2018-08-14': 1},
#  'Sebastian': {'2018-08-14': 1},
#  'HC-Bratschis Luftballon\n\n': {'2018-08-14': 1},
#  'Bernhard': {'2018-08-14': 1},
#  'Benjamin Blümelchen': {'2018-08-14': 2},
#  'Robert L.': {'2018-08-14': 1},
#  'Frank': {'2018-08-14': 1},
#  'Tölpel': {'2018-08-14': 1},
#  'Aarash': {'2018-08-14': 1},
#  'Erdogan': {'2018-08-13': 4, '2018-06-25': 1},
#  'Türken': {'2018-08-13': 1},
#  'Recep Tayyip Erdogan': {'2018-08-13': 1},
#  'Allah': {'2018-08-13': 1, '2018-07-04': 1},
#  'Ambros von Platz': {'2018-08-10': 1},
#  'Wolfgang Ambros': {'2018-08-10': 1},
#  'Ambros’ Hit': {'2018-08-10': 1},
#  'Bella Ciao': {'2018-08-10': 1},
#  'John Otti Band': {'2018-08-10': 1},
#  'Extended Remix': {'2018-08-10': 1},
#  'Christian Hafenecker': {'2018-08-10': 1},
#  'Hans Peter Doskozil': {'2018-08-10': 1},
#  'Burgenländer': {'2018-08-10': 1},
#  'Arbeitspapier': {'2018-08-10': 1},
#  'Kerns': {'2018-08-10': 1},
#  'Bikepolizisten': {'2018-08-09': 1},
#  'Inspektor Thalmeier': {'2018-08-09': 2},
#  'Zielperson': {'2018-08-09': 1},
#  'Thalmeier': {'2018-08-09': 1},
#  'Anarcho-Radler': {'2018-08-09': 1},
#  'Ned': {'2018-08-09': 1},
#  'Blinker': {'2018-08-09': 1},
#  'Naja Madamme': {'2018-08-09': 1},
#  'Martin Ho\n': {'2018-08-08': 1},
#  'Herbert Kickl\n': {'2018-08-08': 1},
#  'Juliane Bogner-Strauß\nKostenanalyse': {'2018-08-08': 1},
#  'Calippo Cola': {'2018-08-08': 1},
#  'Heinz Faßmann\n\r\n\n\n\n': {'2018-08-08': 1},
#  'Mario Kunasek': {'2018-08-08': 1, '2018-06-27': 1},
#  'Elisabeth Köstinger': {'2018-08-08': 1},
#  '\nLabortest': {'2018-08-08': 1},
#  'Pizza': {'2018-05-01': 1},
#  'Golan-Vorfall': {'2018-04-30': 1},
#  'Patrick G.': {'2018-04-30': 2},
#  'Blauhelm': {'2018-04-30': 1},
#  'Künftig': {'2018-04-30': 1},
#  'Branchenexperten': {'2018-04-30': 1},
#  'Mattel': {'2018-04-30': 1},
#  'Fabio Stöger': {'2018-04-30': 1},
#  'Hotspots': {'2018-04-27': 1},
#  'Rapid-Präsident': {'2018-04-27': 1},
#  'Michael Krammer': {'2018-04-27': 1},
#  'Austria-Präsident Wolfgang Katzian': {'2018-04-27': 1},
#  'Torschuss-fähiger Stürmer': {'2018-04-27': 1}}

# %%
import json
json = json.dumps(datumliste)
f = open("./datasets/datumliste_en.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Map personlists together (i.e. "Donald Trump" and "Trump")

# %%
def uniondict(dict1,dict2):
    returndict ={}
    
    allkeys = list(set(list(dict1.keys()) + list(dict2.keys())))
    allvalues = [0] * len(allkeys)
    for i in range(len(allkeys)):
        returndict[allkeys[i]] = allvalues[i]
    
    for key1, value1 in dict1.items():
        returndict[key1] += value1
    for key2, value2 in dict2.items():
        returndict[key2] += value2
                
    return returndict

# %%
def datekompakt(inputdict):
    outputdict = {}

    for name, datelist in inputdict.items():
        for key in inputdict.keys():
            if (name == key):
                continue
            if (name in key) and (len(inputdict[name]) > 3):
                inputdict[name] = uniondict(inputdict[key],datelist)
                inputdict[key] = {}
                break
    for name, datelist  in inputdict.items():
        if datelist != {}:      
            outputdict[name] = datelist
    return outputdict

# %% [markdown]
# ## Clean lists

# %%
datumclean= cleandict_en(datumliste)

# %%
datumkompakt = datekompakt(datumclean)

# %%
import json
json = json.dumps(datumkompakt)
f = open("./datasets/datumliste_en_clean.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Lineplots for persons

# %%
def namenplot(name1, name2, startdatum, enddatum, frequenz, savepfad):
    dict1 = datumkompakt[name1]
    dict2 = datumkompakt[name2]

    datelist = pd.date_range(start=startdatum, end=enddatum).tolist()
    datelist = pd.to_datetime((datelist))

    y_name1 =[]
    y_name2 =[]
    for date in datelist:
        if str(date).split()[0] in dict1:
            y_name1.append(dict1[str(date).split()[0]])
        else:
            y_name1.append(0)
        if str(date).split()[0] in dict2:
            y_name2.append(dict2[str(date).split()[0]])
        else:
            y_name2.append(0)

    tickslist = pd.date_range(start=startdatum, end=enddatum, freq=frequenz).tolist()

    plt.plot(datelist, y_name1,label=name1)
    plt.plot(datelist, y_name2,linestyle='--',label=name2)
    max1 = max(y_name1)
    max2 = max(y_name2)
    plt.axis([startdatum, enddatum, 0, max([max1,max2])+3])

    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
    plt.xlabel('Date')
    plt.xticks(tickslist)
    plt.ylabel('Frequecy')
    plt.suptitle('Mentions in the news ' + name1 + " and " + name2)
    plt.gcf().autofmt_xdate()
    plt.legend()
    plt.savefig(savepfad, dpi=300)
    plt.show()

# %%
namenplot("Hofer", "Kurz", "2018-09-30", "2018-10-30", '1D', './images/trump_obama.png')
